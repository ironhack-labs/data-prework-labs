# %% [markdown]
# # Rock Paper Scissors
#
# Let's play the famous game against our computer.
#
# https://en.wikipedia.org/wiki/Rock%E2%80%93paper%E2%80%93scissors
#
# The use of functions is recommended
#
# ## Goals
# 1. Use of loop
# 2. Data capture by console
# 3. Use if-elif-else
# 4. Use of try-except
# 5. Definition of functions. Modular programming
# 6. Logical operators.
# 7. Print
# 8. Import modules

# %%
# Import the choice function of the random module
# https://stackoverflow.com/questions/306400/how-to-randomly-select-an-item-from-a-list
import random
# Assign to a list the 3 possible options: 'stone', 'paper' or 'scissors'.
options=["stone","paper","scissors"]
# Assign a variable to the maximum number of games: 1, 3, 5, etc ...
maxGames=5
# Assign a variable to the number of games a player must win to win.
# Preferably the value will be based on the number of maximum games
gamesToWin=round((maxGames/2)+.5)
# Define a function that randomly returns one of the 3 options.
# This will correspond to the play of the machine. Totally random.
def randomPlay():
    return(random.choice(options))

# Define a function that asks your choice: 'stone', 'paper' or 'scissors'
# you should only allow one of the 3 options. This is defensive programming.
# If it is not stone, paper or scissors keep asking until it is.
def userPlay():
    userOption=input("Please choose one option: stone, paper or scissors\n")
    a=0
    while a==0:
        if (userOption.lower()=="stone") or (userOption.lower()=="paper") or (userOption.lower()=="scissors"):
            a=1
            return userOption.lower()
        else:
            userOption=input("Please choose one option: stone, paper or scissors\n")


# Define a function that resolves a combat.
# Returns 0 if there is a tie, 1 if the machine wins, 2 if the human player wins
def combat(pc,user):
    if pc==user:
        return 0
    elif (pc=="scissors") and (user=="paper"):
        return 1
    elif (pc=="paper") and (user=="scissors"):
        return 2
    elif (pc=="scissors") and (user=="stone"):
        return 2
    elif (pc=="stone") and (user=="scissors"):
        return 1
    elif (pc=="stone") and (user=="paper"):
        return 2
    elif (pc=="paper") and (user=="stone"):
        return 1
    
# Define a function that shows the choice of each player and the state of the game
# This function should be used every time accumulated points are updated
def statusChoice(a,b,c,d):
    print("The choice of the computer was: ", a)
    print("Games won by the computer: ",b)
    print("The choice of the user was: ", c)
    print("Games won by the user: ",d)


# Create two variables that accumulate the wins of each participant
userWins=0
pcWins=0

# Create a loop that iterates while no player reaches the minimum of wins
# necessary to win. Inside the loop solves the play of the
# machine and ask the player's. Compare them and update the value of the variables
# that accumulate the wins of each participant.
while True:
    pcChoice=randomPlay()
    userChoice=userPlay()
    if ((combat(pcChoice,userChoice))==1):
        pcWins+=1
    elif ((combat(pcChoice,userChoice))==2):
        userWins+=1
    statusChoice(pcChoice,pcWins,userChoice,userWins)
    if (userWins==gamesToWin) or (pcWins==gamesToWin):
        break

# Print by console the winner of the game based on who has more accumulated wins
if userWins>pcWins:
    print("The winner of the game is the user with %d victories" %userWins)
else:
    print("The winner of the game is the computer with %d victories" %pcWins)
# Out:
# Please choose one option: stone, paper or scissors
# paper
# The choice of the computer was:  scissors
# Games won by the computer:  1
# The choice of the user was:  paper
# Games won by the user:  0
# Please choose one option: stone, paper or scissors
# stone
# The choice of the computer was:  scissors
# Games won by the computer:  1
# The choice of the user was:  stone
# Games won by the user:  1
# Please choose one option: stone, paper or scissors
# stone
# The choice of the computer was:  stone
# Games won by the computer:  1
# The choice of the user was:  stone
# Games won by the user:  1
# Please choose one option: stone, paper or scissors
# paper
# The choice of the computer was:  stone
# Games won by the computer:  1
# The choice of the user was:  paper
# Games won by the user:  2
# Please choose one option: stone, paper or scissors
# scissors
# The choice of the computer was:  scissors
# Games won by the computer:  1
# The choice of the user was:  scissors
# Games won by the user:  2
# Please choose one option: stone, paper or scissors
# paper
# The choice of the computer was:  stone
# Games won by the computer:  1
# The choice of the user was:  paper
# Games won by the user:  3
# The winner of the game is the user with 3 victories

# %% [markdown]
# # Bonus: Stone, paper, scissors, lizard, spock
#
# Now the improvement begins.
#
# ![](images/rpsls.jpg)
#
#
# http://www.samkass.com/theories/RPSSL.html
#
# You are asked to impliment some improvements with respect to the simple previous game. In addition, the number of games (which must be ODD) will be requested per console until a valid number is entered.
#
# Improvements:
# * 5 options: stone, paper, scissors, lizard, spock
# * The number of games is requested per console
# Tip: Reuse code that you already use. If you have programmed intelligently, the bonus are simple modifications to the original game.

# %%
# Import the choice function of the random module
import random

# Define a function that asks for an odd number on the keyboard, until it is not valid
# will keep asking
def oddNumber():
    maxGames=int(input("Please introduce an odd number: \n"))
    while True:
        if maxGames%2==0:
            maxGames=int(input("Please introduce an odd number: \n"))
        else:
            return maxGames


# Assign a list of 5 possible options.
options=["stone","paper","scissors", "lizard", "spock"]

# Assign a variable to the maximum number of games: 1, 3, 5, etc ...
# This time the previously defined function is used
maxGame=oddNumber()

# Assign a variable to the number of games a player must win to win.
# Preferably the value will be based on the number of maximum games
gamesToWin=round((maxGame/2)+.5)

# Define a function that randomly returns one of the 5 options.
# This will correspond to the play of the machine. Totally random.
def randomPlay():
    return(random.choice(options))

# Define a function that asks your choice between 5
# you should only allow one of the 5 options. This is defensive programming.
# If it is not valid, keep asking until it is valid.
def userPlay():
    userOption=input("Please choose one option: stone, paper, scissors, lizard or spock\n")
    a=0
    while a==0:
        if (userOption.lower()=="stone") or (userOption.lower()=="paper") or (userOption.lower()=="scissors") or (userOption.lower()=="lizard") or (userOption.lower()=="spock"):
            a=1
            return userOption.lower()
        else:
            userOption=input("Please choose one option: stone, paper, scissors, lizard or spock\n")

# Define a function that resolves a combat.
# Returns 0 if there is a tie, 1 if the machine wins, 2 if the human player wins
# Now there are more options
def combat(pc,user):
    if pc==user:
        return 0
    elif (pc=="scissors"):
        if user=="paper":
            return 1
        elif user=="stone":
            return 2
        elif user=="spock":
            return 2
        elif user=="lizard":
            return 1
    elif (pc=="paper"):
        if (user=="scissors"):
            return 2
        elif user=="stone":
            return 1
        elif user=="spock":
            return 1
        elif user=="lizard":
            return 2
    elif (pc=="stone"):
        if (user=="paper"):
            return 2
        elif user=="scissors":
            return 1
        elif user=="spock":
            return 2
        elif user=="lizard":
            return 1
    elif (pc=="spock"):
        if (user=="paper"):
            return 2
        elif user=="stone":
            return 1
        elif user=="scissors":
            return 1
        elif user=="lizard":
            return 2
    elif (pc=="lizard"):
        if (user=="paper"):
            return 1
        elif user=="stone":
            return 2
        elif user=="spock":
            return 1
        elif user=="scissors":
            return 2
    

    
# Define a function that shows the choice of each player and the state of the game
# This function should be used every time accumulated points are updated
def statusChoice(a,b,c,d):
    print("The choice of the computer was: ", a)
    print("Games won by the computer: ",b)
    print("The choice of the user was: ", c)
    print("Games won by the user: ",d)
    
# Create two variables that accumulate the wins of each participant
userWins=0
pcWins=0
# Create a loop that iterates while no player reaches the minimum of wins
# necessary to win. Inside the loop solves the play of the
# machine and ask the player's. Compare them and update the value of the variables
# that accumulate the wins of each participant.
while True:
    pcChoice=randomPlay()
    userChoice=userPlay()
    if ((combat(pcChoice,userChoice))==1):
        pcWins+=1
    elif ((combat(pcChoice,userChoice))==2):
        userWins+=1
    statusChoice(pcChoice,pcWins,userChoice,userWins)
    if (userWins==gamesToWin) or (pcWins==gamesToWin):
        break
    
    
# Print by console the winner of the game based on who has more accumulated wins
if userWins>pcWins:
    print("The winner of the game is the user with %d victories" %userWins)
else:
    print("The winner of the game is the computer with %d victories" %pcWins)
# Out:
# Please introduce an odd number:
# 4
# Please introduce an odd number:
# 5
# Please choose one option: stone, paper, scissors, lizard or spock
# stone
# The choice of the computer was:  stone
# Games won by the computer:  0
# The choice of the user was:  stone
# Games won by the user:  0
# Please choose one option: stone, paper, scissors, lizard or spock
# paper
# The choice of the computer was:  lizard
# Games won by the computer:  1
# The choice of the user was:  paper
# Games won by the user:  0
# Please choose one option: stone, paper, scissors, lizard or spock
# spock
# The choice of the computer was:  spock
# Games won by the computer:  1
# The choice of the user was:  spock
# Games won by the user:  0
# Please choose one option: stone, paper, scissors, lizard or spock
# lizard
# The choice of the computer was:  lizard
# Games won by the computer:  1
# The choice of the user was:  lizard
# Games won by the user:  0
# Please choose one option: stone, paper, scissors, lizard or spock
# paper
# The choice of the computer was:  paper
# Games won by the computer:  1
# The choice of the user was:  paper
# Games won by the user:  0
# Please choose one option: stone, paper, scissors, lizard or spock
# paper
# The choice of the computer was:  spock
# Games won by the computer:  1
# The choice of the user was:  paper
# Games won by the user:  1
# Please choose one option: stone, paper, scissors, lizard or spock
# stone
# The choice of the computer was:  spock
# Games won by the computer:  2
# The choice of the user was:  stone
# Games won by the user:  1
# Please choose one option: stone, paper, scissors, lizard or spock
# lizard
# The choice of the computer was:  paper
# Games won by the computer:  2
# The choice of the user was:  lizard
# Games won by the user:  2
# Please choose one option: stone, paper, scissors, lizard or spock
# spock
# The choice of the computer was:  lizard
# Games won by the computer:  3
# The choice of the user was:  spock
# Games won by the user:  2
# The winner of the game is the computer with 3 victories
