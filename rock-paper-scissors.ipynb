# %% [markdown]
# # Rock Paper Scissors
#
# Let's play the famous game against our computer.
#
# https://en.wikipedia.org/wiki/Rock%E2%80%93paper%E2%80%93scissors
#
# The use of functions is recommended
#
# ## Goals
# 1. Use of loop
# 2. Data capture by console
# 3. Use if-elif-else
# 4. Use of try-except
# 5. Definition of functions. Modular programming
# 6. Logical operators.
# 7. Print
# 8. Import modules

# %%
# Import the choice function of the random module
# https://stackoverflow.com/questions/306400/how-to-randomly-select-an-item-from-a-list

import random

# Assign to a list the 3 possible options: 'stone', 'paper' or 'scissors'.

game = ['stone', 'paper', 'scissors']

# Assign a variable to the maximum number of games: 1, 3, 5, etc ...

game_max_nb = 5

# Assign a variable to the number of games a player must win to win.
# Preferably the value will be based on the number of maximum games

game_to_win = int((game_max_nb / 2) + 0.5)

# Define a function that randomly returns one of the 3 options.
# This will correspond to the play of the machine. Totally random.

computer = False

def ask_computer():
    global computer
    computer = random.choice(game)
    return computer

# Define a function that asks your choice: 'stone', 'paper' or 'scissors'
# you should only allow one of the 3 options. This is defensive programming.
# If it is not stone, paper or scissors keep asking until it is.

player = False

def ask_player():
    global player
    player = input("Choose stone, paper, or scissors : ")
    while player not in game:
        player = input("Check your spelling : stone, paper or scissors ? ")
    return player

# Define a function that resolves a combat.
# Returns 0 if there is a tie, 1 if the machine wins, 2 if the human player wins

combat = False

def resolve_combat(c, p):
    global combat
    if p == c:
        combat = 0
    elif p == 'stone':
        if c == 'paper':
            combat = 1
        else:
            combat = 2
    elif p == 'paper':
        if c == 'stone':
            combat = 2
        else:
            combat = 1
    elif p == 'scissors':
        if c == 'stone':
            combat = 1
        else:
            combat = 2
    return combat
    
# Define a function that shows the choice of each player and the state of the game
# This function should be used every time accumulated points are updated

def result_combat():
    if combat == 0:
        print(computer, "vs", player, "It's a tie!")
    elif combat == 1:
        print(computer, "vs", player, "Computer wins!")
    elif combat == 2:
        print(computer, "vs", player, "Player wins!")
    
# Create two variables that accumulate the wins of each participant

computer_wins = 0
player_wins = 0

# Create a loop that iterates while no player reaches the minimum of wins
# necessary to win. Inside the loop solves the play of the
# machine and ask the player's. Compare them and update the value of the variables
# that accumulate the wins of each participant.

game_nb = 0

while game_nb < game_max_nb:
    ask_computer()
    ask_player()
    resolve_combat(computer, player)
    if combat == 0:
        pass
    elif combat == 1:
        computer_wins += 1
    elif combat == 2:
        player_wins += 1
    result_combat()
    game_nb += 1
    
# Print by console the winner of the game based on who has more accumulated wins

if computer_wins >= game_to_win:
    print("Computer wins!")
elif player_wins >= game_to_win:
    print("You win!")
else:
    print("You nor the computer won enough combat.")
# Out:
# Choose stone, paper, or scissors : paper
# scissors vs paper Computer wins!
# Choose stone, paper, or scissors : stone
# stone vs stone It's a tie!
# Choose stone, paper, or scissors : scissors
# stone vs scissors Computer wins!
# Choose stone, paper, or scissors : stone
# paper vs stone Computer wins!
# Choose stone, paper, or scissors : stone
# stone vs stone It's a tie!
# Computer wins!

# %% [markdown]
# # Bonus: Stone, paper, scissors, lizard, spock
#
# Now the improvement begins.
#
# ![](images/rpsls.jpg)
#
#
# http://www.samkass.com/theories/RPSSL.html
#
# You are asked to impliment some improvements with respect to the simple previous game. In addition, the number of games (which must be ODD) will be requested per console until a valid number is entered.
#
# Improvements:
# * 5 options: stone, paper, scissors, lizard, spock
# * The number of games is requested per console
# Tip: Reuse code that you already use. If you have programmed intelligently, the bonus are simple modifications to the original game.

# %%
# Import the choice function of the random module

import random

# Define a function that asks for an odd number on the keyboard, until it is not valid
# will keep asking

game_max_nb = int(input("Define an odd number of combat :"))
while game_max_nb % 2 == 0:
    game_max_nb = int(input("Number must be odd :"))
    
# Assign a list of 5 possible options.

game = ['stone', 'paper', 'scissors', 'lizard', 'spock']

# Assign a variable to the maximum number of games: 1, 3, 5, etc ...
# This time the previously defined function is used

# Assign a variable to the number of games a player must win to win.
# Preferably the value will be based on the number of maximum games

game_to_win = int((game_max_nb / 2) + 0.5)

# Define a function that randomly returns one of the 5 options.
# This will correspond to the play of the machine. Totally random.

computer = False

def ask_computer():
    global computer
    computer = random.choice(game)
    return computer

# Define a function that asks your choice between 5
# you should only allow one of the 5 options. This is defensive programming.
# If it is not valid, keep asking until it is valid.

player = False

def ask_player():
    global player
    player = input("Choose stone, paper, scissors, lizard or spock : ")
    while player not in game:
        player = input("Check your spelling : stone, paper, scissors, lizard or spock ? ")
    return player

# Define a function that resolves a combat.
# Returns 0 if there is a tie, 1 if the machine wins, 2 if the human player wins
# Now there are more options
 
combat = False

def resolve_combat(c, p):
    global combat
    if p == c:
        combat = 0
    elif p == 'stone':
        if c == 'paper':
            combat = 1
        elif c == 'scissors':
            combat = 2
        elif c == 'lizard':
            combat = 2
        else:
            combat = 1
    elif p == 'paper':
        if c == 'stone':
            combat = 2
        elif c == 'lizard':
            combat = 1
        elif c == 'spock':
            combat = 2
        else:
            combat = 1
    elif p == 'scissors':
        if c == 'stone':
            combat = 1
        elif c == 'lizard':
            combat = 2
        elif c == 'spock':
            combat = 1
        else:
            combat = 2
    elif p == 'lizard':
        if c == 'stone':
            combat = 1
        elif c == 'paper':
            combat = 2
        elif c == 'scissors':
            combat = 1
        else:
            combat = 2
    elif p == 'spock':
        if c == 'stone':
            combat = 2
        elif c == 'paper':
            combat = 1
        elif c == 'scissors':
            combat = 2
        else:
            combat = 1
    return combat
    
# Define a function that shows the choice of each player and the state of the game
# This function should be used every time accumulated points are updated

def result_combat():
    if combat == 0:
        print(computer, "vs", player, "It's a tie!")
    elif combat == 1:
        print(computer, "vs", player, "Computer wins!")
    elif combat == 2:
        print(computer, "vs", player, "Player wins!")
    
# Create two variables that accumulate the wins of each participant

computer_wins = 0
player_wins = 0

# Create a loop that iterates while no player reaches the minimum of wins
# necessary to win. Inside the loop solves the play of the
# machine and ask the player's. Compare them and update the value of the variables
# that accumulate the wins of each participant.

game_nb = 0

while game_nb < game_max_nb:
    ask_computer()
    ask_player()
    resolve_combat(computer, player)
    if combat == 0:
        pass
    elif combat == 1:
        computer_wins += 1
    elif combat == 2:
        player_wins += 1
    result_combat()
    game_nb += 1
    
# Print by console the winner of the game based on who has more accumulated wins

if computer_wins >= game_to_win:
    print("Computer wins!")
elif player_wins >= game_to_win:
    print("You win!")
else:
    print("You nor the computer won enough combat.")
# Out:
# Define an odd number of combat :5
# Choose stone, paper, scissors, lizard or spock : spock
# scissors vs spock Player wins!
# Choose stone, paper, scissors, lizard or spock : lizard
# spock vs lizard Player wins!
# Choose stone, paper, scissors, lizard or spock : stone
# spock vs stone Computer wins!
# Choose stone, paper, scissors, lizard or spock : paper
# stone vs paper Player wins!
# Choose stone, paper, scissors, lizard or spock : scissors
# spock vs scissors Computer wins!
# You win!
